# %%
import pandas as pd
import matplotlib as plt
glims = pd.read_csv('glims_clean.csv')

# %%
pd.set_option('display.max_columns', 50)
glims.head()
# Out:
#    Unnamed: 0  ANLYS_ID         GLAC_ID       AREA    DB_AREA  WIDTH  \
# 0           0    101215  G286929E46788S   12.42590   12.42920    0.0
# 1           1    101146  G286719E46755S   80.28420   80.31270    0.0
# 2           8    101162  G286570E46600S  118.68100  118.73700    0.0
# 3          14    101193  G286829E48560S   41.24430   41.25890    0.0
# 4          15    101581  G287590E47667S    5.76485    5.76413    0.0
#
#      LENGTH  PRIMECLASS  MIN_ELEV  MEAN_ELEV  MAX_ELEV             SRC_DATE  \
# 0   4786.66           0         0          0         0  2007-09-06T00:00:00
# 1  10225.60           0         0          0         0  2007-09-06T00:00:00
# 2  27183.10           0         0          0         0  2007-09-06T00:00:00
# 3  14192.90           0         0          0         0  2007-09-06T00:00:00
# 4   3161.54           0         0          0         0  2007-09-06T00:00:00
#
#   REC_STATUS GLAC_NAME WGMS_ID LOCAL_ID GLAC_STAT            GEOG_AREA  \
# ...

# %%
geog_areas = glims.GEOG_AREA.unique()
geog_areas
# Out:
# array(['Antarctic Peninsula', 'Svalbard, Jan Mayen, and Bouvet',
#        'Various (GlobGlacier)', 'Northern Cordillera',
#        'Randolph Glacier Inventory; Umbrella RC for merging the RGI into GLIMS',
#        'Various (NSIDC)', 'Mongolia', 'French Alps',
#        'Himalaya (India, Nepal, Bhutan)', 'Conterminous USA',
#        'Swiss Alps', 'Alaska', 'China', 'Iran', 'Khumbu Area',
#        'Austrian Alps', 'Central Asia', 'Norway', 'Caucausus Region',
#        'Italy', 'Argentina', 'Siberian Mountains', 'Italian Alps',
#        'Russian Glaciers (exact boundaries of RC to be defined)',
#        'Irian Jaya', 'Iceland', 'Sweden',
#        'Russian and former Soviet Union glaciers',
#        'Southwestern Asia (Pakistan + Afghanistan)', 'Canada',
#        'Kerguelen Island', 'Cordillera Blanca, Peru',
#        'Chilean glaciers, between -18 and -56 degrees latitude',
#        'Northeast Greenland', 'East Central Greenland', 'Chile',
# ...
