# %%
import pandas as pd
import matplotlib as plt

# %%
glims = pd.read_csv('glims_csvutf8.csv')
pd.set_option('display.max_columns', 50)
glims.head(20)
#can see that there are repeated rows in dataframe
# Out:
#       LINE_TYPE  ANLYS_ID         GLAC_ID           ANLYS_TIME       AREA  \
# 0    glac_bound    101215  G286929E46788S  2012-04-20T00:00:00   12.42590
# 1   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 2   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 3   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 4   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 5   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 6   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 7   intrnl_rock    101146  G286719E46755S  2012-04-20T00:00:00   80.28420
# 8   intrnl_rock    101162  G286570E46600S  2012-04-20T00:00:00  118.68100
# 9   intrnl_rock    101162  G286570E46600S  2012-04-20T00:00:00  118.68100
# 10  intrnl_rock    101162  G286570E46600S  2012-04-20T00:00:00  118.68100
# 11  intrnl_rock    101162  G286570E46600S  2012-04-20T00:00:00  118.68100
# ...

# %%
#Want to isolate unique ANLYS_ID
#variables we care about: ANLYS_ID, GLAC_ID, AREA, DB_AREA, WIDTH, LENGTH, PRIMECLASS, MIN_ELEV, MEAN_ELEV, MAX_ELEV, 
# SRC_DATE, REC_STATUS, GLAC_NAME, GLAC_STAT, GEOG_AREA, PARENT_ID
glims_unique = glims.drop_duplicates(subset=['ANLYS_ID'])
glims_clean = glims_unique.drop(labels=['LINE_TYPE','ANLYS_TIME','SUBM_ID','RELEASE_DT'], axis=1)
glims_clean = glims_clean.drop(labels=['PROC_DESC','RC_ID','CHIEF_AFFL'], axis=1)
glims_clean.head(10)
# Out:
#     ANLYS_ID         GLAC_ID       AREA    DB_AREA  WIDTH    LENGTH  \
# 0     101215  G286929E46788S   12.42590   12.42920    0.0   4786.66
# 1     101146  G286719E46755S   80.28420   80.31270    0.0  10225.60
# 8     101162  G286570E46600S  118.68100  118.73700    0.0  27183.10
# 14    101193  G286829E48560S   41.24430   41.25890    0.0  14192.90
# 15    101581  G287590E47667S    5.76485    5.76413    0.0   3161.54
# 16    101257  G290552E54592S   22.61050   22.55730    0.0   7782.78
# 17    101170  G286431E47184S  265.86600  266.01100    0.0  40678.70
# 18    101270  G290587E54704S    7.89722    7.87846    0.0   4317.78
# 19    101153  G286716E46597S   87.81580   87.81190    0.0  20432.20
# 21    101752  G286599E47361S   77.22530   77.16470    0.0  24776.40
#
#     PRIMECLASS  MIN_ELEV  MEAN_ELEV  MAX_ELEV             SRC_DATE REC_STATUS  \
# 0            0         0          0         0  2007-09-06T00:00:00       okay
# ...

# %%
#adding columns for year, month
glims_clean['DATE'] = pd.to_datetime(glims_clean['SRC_DATE'])
glims_clean['YEAR'] = glims_clean['DATE'].dt.year
glims_clean['MONTH'] = glims_clean['DATE'].dt.month

# %%
glims_clean.head(50)
# Out:
#      ANLYS_ID         GLAC_ID        AREA     DB_AREA  WIDTH    LENGTH  \
# 0      101215  G286929E46788S   12.425900   12.429200    0.0   4786.66
# 1      101146  G286719E46755S   80.284200   80.312700    0.0  10225.60
# 8      101162  G286570E46600S  118.681000  118.737000    0.0  27183.10
# 14     101193  G286829E48560S   41.244300   41.258900    0.0  14192.90
# 15     101581  G287590E47667S    5.764850    5.764130    0.0   3161.54
# 16     101257  G290552E54592S   22.610500   22.557300    0.0   7782.78
# 17     101170  G286431E47184S  265.866000  266.011000    0.0  40678.70
# 18     101270  G290587E54704S    7.897220    7.878460    0.0   4317.78
# 19     101153  G286716E46597S   87.815800   87.811900    0.0  20432.20
# 21     101752  G286599E47361S   77.225300   77.164700    0.0  24776.40
# 22     101755  G286552E47076S   42.202900   41.769200    0.0   9705.71
# 23     102307  G286719E46755S   82.328100   82.357200    0.0  10536.70
# ...

# %%
export_csv = glims_clean.to_csv(r'C:\Users\Chloe\Documents\Data science team\glims_clean.csv',header=True)
